# %% [markdown]
# I named multiple different strings and then printed them out together using the print() function. However, when I originially printed them out they weren't seperated into new lines so I learned about the newline function which seperates each line, so I added that to my code.

# %%
name = "My name : Sylvia"

# %%
color = "My favorite color : Blue"

# %%
activity = "My favorite acitvity : Playing sports"

# %%
animal = "My favorite animal : Penguin"

# %%
print(name, color, activity, animal, sep='\n')
# Out:
# My name : Sylvia
# My favorite color : Blue
# My favorite acitvity : Playing sports
# My favorite animal : Penguin

# %% [markdown]
# I created a dictionary using the code dict and listing the values

# %%
dict = {"CTA" : "L" , "GGA" : "G" , "GTG" : "V" , "ATT" : "I" , "TCG" : "S"}

# %%
type(dict)
# Out:
# dict

# %% [markdown]
# To creacte a string sequence I listed the codons with spaces inbetween

# %%
seq = "CTA GGA GTG ATT TCG"

# %%
type(seq)
# Out:
# str

# %% [markdown]
# To split the string into three letter codons I just used the split() to seperate the codons by the spaces that I had originally wrote in

# %%
seq.split()
# Out:
# ['CTA', 'GGA', 'GTG', 'ATT', 'TCG']

# %%
dict.values()
# Out:
# dict_values(['L', 'G', 'V', 'I', 'S'])

# %%
dict2 = {"CTA" : "Leu" , "GGA" : "Gly" , "GTG" : "Val" , "ATT" : "Ile" , "TCG" : "Ser"}

# %%
dict.update(dict2)

# %%
dict
# Out:
# {'CTA': 'Leu', 'GGA': 'Gly', 'GTG': 'Val', 'ATT': 'Ile', 'TCG': 'Ser'}

# %%
dict.values()
# Out:
# dict_values(['Leu', 'Gly', 'Val', 'Ile', 'Ser'])

# %%
amino_acid_seq = ["Leu", "Gly", "Val", "Ile", "Ser"]

# %%
print(amino_acid_seq)
# Out:
# ['Leu', 'Gly', 'Val', 'Ile', 'Ser']
